# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
credit_df = pd.read_csv("Credit_card.csv")

# %%
credit_df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
label = pd.read_csv("Credit_card_label.csv")

# %%
label.head()
# Out:
#     Ind_ID  label
# 0  5008827      1
# 1  5009744      1
# 2  5009746      1
# 3  5009749      1
# 4  5009752      1

# %%
credit_df = credit_df.merge(label, on="Ind_ID", how="left")

# %%
credit_df
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
credit_df.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
credit_df.isna().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
credit_df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
credit_df.drop(columns = ("Type_Occupation"), inplace=True)

# %%
credit_df.isna().sum()
# Out:
# Ind_ID             0
# GENDER             7
# Car_Owner          0
# Propert_Owner      0
# CHILDREN           0
# Annual_income     23
# Type_Income        0
# EDUCATION          0
# Marital_status     0
# Housing_type       0
# Birthday_count    22
# Employed_days      0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# EMAIL_ID           0
# Family_Members     0
# label              0
# dtype: int64

# %%
credit_df.dropna(inplace=True)

# %%
credit_df.isna().sum()
# Out:
# Ind_ID            0
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label             0
# dtype: int64

# %%
credit_df.duplicated().sum()
# Out:
# 0

# %%
average_income = credit_df["Annual_income"].mean()
average_income
# Out:
# 190775.04846256683

# %%
gender_income = credit_df.groupby("GENDER")["Annual_income"].mean()
gender_income
# Out:
# GENDER
# F    172391.840021
# M    222485.245902
# Name: Annual_income, dtype: float64

# %%
sns.barplot(x=gender_income.index, y = gender_income.values)
plt.title("Average Income by Gender")
plt.xlabel("Genders")
plt.xlabel("Income")
plt.show()

# %%
label_counts = credit_df["label"].value_counts()
label_counts
# Out:
# 0    1336
# 1     160
# Name: label, dtype: int64

# %%
plt.pie(label_counts, labels=["Credits Approved", "Credits Rejected"], autopct="%1.1f%%")
plt.title("Credit Approval Status")
plt.show()

# %%
credit_df.groupby("Type_Income")["Annual_income"].mean()
# Out:
# Type_Income
# Commercial associate    233880.169972
# Pensioner               154964.866795
# State servant           210130.434783
# Working                 180154.579974
# Name: Annual_income, dtype: float64

# %%
credit_df.groupby("Marital_status")["Employed_days"].max()
# Out:
# Marital_status
# Civil marriage          365243
# Married                 365243
# Separated               365243
# Single / not married    365243
# Widow                   365243
# Name: Employed_days, dtype: int64

# %%
credit_df.groupby("Housing_type")["Family_Members"].sum()
# Out:
# Housing_type
# Co-op apartment           5
# House / apartment      2900
# Municipal apartment      92
# Office apartment         21
# Rented apartment         46
# With parents            175
# Name: Family_Members, dtype: int64

# %%
credit_df.groupby("GENDER")["Birthday_count"].min() * -1
# Out:
# GENDER
# F    24946.0
# M    24662.0
# Name: Birthday_count, dtype: float64

# %%
credit_df.groupby("Propert_Owner")["Annual_income"].mean()
# Out:
# Propert_Owner
# N    183343.352601
# Y    194722.899181
# Name: Annual_income, dtype: float64

# %%
credit_df.groupby("EDUCATION")["Mobile_phone"].max()
# Out:
# EDUCATION
# Academic degree                  1
# Higher education                 1
# Incomplete higher                1
# Lower secondary                  1
# Secondary / secondary special    1
# Name: Mobile_phone, dtype: int64

# %%
credit_df.groupby("CHILDREN")["Annual_income"].sum()
# Out:
# CHILDREN
# 0     191703172.5
# 1      64218600.0
# 2      26226900.0
# 3       2845800.0
# 4        180000.0
# 14       225000.0
# Name: Annual_income, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x="Marital_status", y="Annual_income", data=credit_df)
plt.title("Annual Income Variation by Marital Status")
plt.show()

# %%
sns.violinplot(x="GENDER", y="Birthday_count", data=credit_df)
plt.title("Distribution of birthday count by gender")
plt.show()

# %%
credit_df.groupby("Marital_status")["Family_Members"].sum().plot(kind="pie", autopct="%1.1f%%")
plt.title("Family Members Distribution by Marital Status")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(12,8))
credit_df.boxplot(column="Annual_income", by="EDUCATION")
plt.title("Annual Income Variation by Education Level")
plt.show()

# %%
credit_df
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 4     5009752      F         Y             N         0       315000.0
# 6     5009754      F         Y             N         0       315000.0
# 7     5009894      F         N             N         0       180000.0
# ...       ...    ...       ...           ...       ...            ...
# 1542  5118268      M         Y             N         1       360000.0
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
credit_data = credit_df[["Car_Owner", "Propert_Owner", "Annual_income", "EDUCATION", "label"]]

# %%
credit_data
# Out:
#      Car_Owner Propert_Owner  Annual_income                      EDUCATION  \
# 0            Y             Y       180000.0               Higher education
# 1            Y             N       315000.0               Higher education
# 4            Y             N       315000.0               Higher education
# 6            Y             N       315000.0               Higher education
# 7            N             N       180000.0  Secondary / secondary special
# ...        ...           ...            ...                            ...
# 1542         Y             N       360000.0  Secondary / secondary special
# 1544         N             N       225000.0              Incomplete higher
# 1545         Y             Y       180000.0               Higher education
# 1546         Y             N       270000.0  Secondary / secondary special
# 1547         Y             Y       225000.0               Higher education
#
#       label
# 0         1
# 1         1
# 4         1
# 6         1
# ...

# %%
from sklearn import preprocessing

labelencoder = preprocessing.LabelEncoder()

# %%
credit_data["Car_Owner"] = labelencoder.fit_transform(credit_data["Car_Owner"])
credit_data["Propert_Owner"] = labelencoder.fit_transform(credit_data["Propert_Owner"])
credit_data["EDUCATION"] = labelencoder.fit_transform(credit_data["EDUCATION"])
# Out:
# <ipython-input-40-30ce10c06bd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   credit_data["Car_Owner"] = labelencoder.fit_transform(credit_data["Car_Owner"])
# <ipython-input-40-30ce10c06bd6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   credit_data["Propert_Owner"] = labelencoder.fit_transform(credit_data["Propert_Owner"])
# <ipython-input-40-30ce10c06bd6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
credit_data
# Out:
#       Car_Owner  Propert_Owner  Annual_income  EDUCATION  label
# 0             1              1       180000.0          1      1
# 1             1              0       315000.0          1      1
# 4             1              0       315000.0          1      1
# 6             1              0       315000.0          1      1
# 7             0              0       180000.0          4      1
# ...         ...            ...            ...        ...    ...
# 1542          1              0       360000.0          4      0
# 1544          0              0       225000.0          2      0
# 1545          1              1       180000.0          1      0
# 1546          1              0       270000.0          4      0
# 1547          1              1       225000.0          1      0
#
# [1496 rows x 5 columns]

# %%
X = credit_data.iloc[:, :-1]

# %%
y = credit_data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
from sklearn.metrics import accuracy_score

def modelPerformance(predictions):
  print("Accuracy score on model is {}".format(accuracy_score(y_test, predictions)))

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()
log_model.fit(scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_predictions = log_model.predict(scaled_X_test)

# %%
modelPerformance(log_predictions)
# Out:
# Accuracy score on model is 0.87

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.neighbors import KNeighborsClassifier

param_grid = {"n_neighbors": [3,5,7,9,11],
              "weights": ["uniform", "distance"],
              "algorithm": ["auto", "kd_tree"]}

gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv=2)

# %%
gridkn.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'kd_tree'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'uniform'}

# %%
knpreds = gridkn.predict(scaled_X_test)

# %%
modelPerformance(knpreds)
# Out:
# Accuracy score on model is 0.87

# %%
from sklearn.svm import SVC

svm = SVC()
param_grid_svr = {"C": [0.01,0.1,0.5,1],
                  "kernel": ["linear", "rbf", "poly"]}

gridsvr = GridSearchCV(svm,param_grid_svr)

# %%
gridsvr.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
pred_svc = gridsvr.predict(scaled_X_test)
modelPerformance(pred_svc)
# Out:
# Accuracy score on model is 0.87

# %%
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    "criterion": ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None, 10, 20, 30, 40, 50],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4]
}

grid_search_tree = GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=param_grid)

# %%
grid_search_tree.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_search_tree.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
preds = grid_search_tree.predict(scaled_X_test)

# %%
modelPerformance(preds)
# Out:
# Accuracy score on model is 0.87

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()

n_estimators = [32, 64, 128, 256]
max_features = [2,3,4]

bootstrap = [True, False]
oob_score = [True, False]

# %%
param_grid_rfc = {
    "n_estimators": n_estimators,
    "max_features": max_features,
    "bootstrap": bootstrap,
    "oob_score": oob_score

}

# %%
grid_rfc = GridSearchCV(rfc_model, param_grid_rfc)

# %%
grid_rfc.fit(scaled_X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 434, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
# ...

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 4, 'n_estimators': 256, 'oob_score': True}

# %%
pred_rfc = grid_rfc.predict(scaled_X_test)

# %%
modelPerformance(pred_rfc)
# Out:
# Accuracy score on model is 0.8566666666666667

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_classifier = AdaBoostClassifier()

ada_param_grid = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01,0.1,1,10]
}

ada_grid_search = GridSearchCV(ada_classifier, ada_param_grid, cv=2)

# %%
ada_grid_search.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=AdaBoostClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
ada_pred = ada_grid_search.predict(scaled_X_test)

# %%
modelPerformance(ada_pred)
# Out:
# Accuracy score on model is 0.87

# %%
from xgboost import XGBClassifier
xgb_classifier = XGBClassifier()

xgb_param_grid = {
    "n_estimators": [60,80,100,500,1000],
    "learning_rate": [0.01,0.1,0.2,0.3,0.5],
    "max_depth": [4,5,7]
}

# %%
xgb_grid_search = GridSearchCV(xgb_classifier, xgb_param_grid, cv=3)

# %%
xgb_grid_search.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
# ...

# %%
xgb_pred = xgb_grid_search.predict(scaled_X_test)

# %%
xgb_grid_search.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 60}

# %%
modelPerformance(xgb_pred)
# Out:
# Accuracy score on model is 0.87
